# %% [markdown]
# <a href="https://colab.research.google.com/github/senazeynepayar/bby162/blob/master/basit_katalog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dosya = open('kitap_listesi.txt','w+')


kitap_adi = [1984, 
             "Kürk Mantolu Madonna",
             "Bugün Kalan Hayatımın İlk Günü",
             "Uçurtma Avcısı",
             "Suç ve Ceza",
             "Hayvan Çiftliği",
             "Sineklerin Tanrısı",
             "Simyacı",
             "Satranç",
             "Fareler ve İnsanlar",
             "Tutunamayanlar"]

kitap_yazari  = ["George Orwell",
                 "Sabahattin Ali",
                 "Maud Ankaoua",
                 "Khaled Hosseini",
                 "Fyodor Mihayloviç Dostoyevski",
                 "George Orwell",
                 "William Golding",
                 "Paulo Coelho",
                 "Stefan Zweig",
                 "John Steinbeck",
                 "Oğuz Atay"]

kitap_basimyili  = [2000,
                    1998,
                    2019,
                    2004,
                    2006,
                    2001,
                    2006,
                    2010,
                    2012,
                    2012,
                    2000]

kitap_isbn  = [9789750718533,
               9789753638029,
               9786058276642,
               9789752891456,
               9789754589023,
               9789750719387,
               9789754582901,
               9789750726439,
               9786053606116,
               9789755705859,
               9789754700114]

kitap_yayinevi  = ["Can Yayınları",
                   "Yapı Kredi Yayınları",
                   "Yan Pasaj",
                   "Everest Yayınları",
                   "İş Bankası Kültür Yayınları",
                   "Can Yayınları",
                   "İş Bankası Kültür Yayınları",
                   "Can Yayınları",
                   "İş Bankası Kültür Yayınları",
                   "Sel Yayıncılık",
                   "İletişim Yayınevi"]
kitap_kunye = [kitap_adi, kitap_yazari, kitap_basimyili, kitap_isbn, kitap_yayinevi]

print("KİTAP KÜNYELERİ")


i=0
while (i < len(kitap_adi)):
  print((i+1),".Kitap")
  j=0

  while (j < len(kitap_kunye)):
    print(kitap_kunye[j][i])
    j += 1

  i+=1
  print("")



kitapadi = input("Kitap Adı Giriniz...")
kitapyazari = input("Kitap Yazarınını Giriniz...")
kitapbasimyili = input("Kitap Basım Yılını Giriniz...")
kitapisbn = input("Kitap ISBN Giriniz...")
kitapyayinevi = input("Kitap Yayinevini Giriniz...")
kitap_adi.insert(len(kitap_adi),kitapadi)
kitap_yazari.insert(len(kitap_yazari),kitapyazari)
kitap_basimyili.insert(len(kitap_basimyili),kitapbasimyili)
kitap_isbn.insert(len(kitap_isbn),kitapisbn)
kitap_yayinevi.insert(len(kitap_yayinevi),kitapyayinevi)

print("Kaydınız Tamamlanmıştır...")
print("")
print("KİTAP KÜNYELERİ")


i=0
while (i < len(kitap_adi)):
  print((i+1),".Kitap")
  j=0

  while (j < len(kitap_kunye)):
    print(kitap_kunye[j][i])
    j += 1

  i+=1
  print("")


  dosya.close()
# Out:
# KİTAP KÜNYELERİ
# 1 .Kitap
# 1984
# George Orwell
# 2000
# 9789750718533
# Can Yayınları
#
# 2 .Kitap
# Kürk Mantolu Madonna
# Sabahattin Ali
# 1998
# 9789753638029
# Yapı Kredi Yayınları
#
# 3 .Kitap
# Bugün Kalan Hayatımın İlk Günü
# Maud Ankaoua
# 2019
# 9786058276642
# Yan Pasaj
#
# 4 .Kitap
# Uçurtma Avcısı
# Khaled Hosseini
# 2004
# 9789752891456
# Everest Yayınları
#
# 5 .Kitap
# Suç ve Ceza
# Fyodor Mihayloviç Dostoyevski
# 2006
# 9789754589023
# İş Bankası Kültür Yayınları
#
# 6 .Kitap
# Hayvan Çiftliği
# George Orwell
# 2001
# 9789750719387
# Can Yayınları
#
# 7 .Kitap
# Sineklerin Tanrısı
# William Golding
# 2006
# 9789754582901
# İş Bankası Kültür Yayınları
#
# 8 .Kitap
# Simyacı
# Paulo Coelho
# 2010
# 9789750726439
# Can Yayınları
#
# 9 .Kitap
# Satranç
# Stefan Zweig
# 2012
# 9786053606116
# İş Bankası Kültür Yayınları
#
# 10 .Kitap
# Fareler ve İnsanlar
# John Steinbeck
# 2012
# 9789755705859
# Sel Yayıncılık
#
# 11 .Kitap
# Tutunamayanlar
# Oğuz Atay
# 2000
# ...
